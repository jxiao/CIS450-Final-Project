# %% [markdown]
# # Milestone 3: Processing and Cleaning

# %%
import pandas as pd
from google.colab import drive

# %%
#Make sure that you have the following path in your drive: /content/drive/My Drive/CIS450 Project/
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ### Books Data

# %%
books_df = pd.read_csv('/content/drive/My Drive/CIS450 Project/Books/GoodReads_100k_books.csv')

# %%
df = pd.DataFrame(list(books_df['author']))

# %% [markdown]
# ## Movies Data

# %%
movies_credits_df = pd.read_csv('/content/drive/My Drive/CIS450 Project/Movies/movies_credits.csv')
movies_metadata_df = pd.read_csv('/content/drive/My Drive/CIS450 Project/Movies/movies_metadata.csv')
movies_ratings_df = pd.read_csv('/content/drive/My Drive/CIS450 Project/Movies/ratings.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
movies_credits_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-62123654d20f> in <module>
# ----> 1 movies_credits_df
#
# NameError: name 'movies_credits_df' is not defined

# %%
movies_metadata_df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
movies_ratings_df
# Out:
#           userId  movieId  rating   timestamp
# 0              1      110     1.0  1425941529
# 1              1      147     4.5  1425942435
# 2              1      858     5.0  1425941523
# 3              1     1221     5.0  1425941546
# 4              1     1246     5.0  1425941556
# ...          ...      ...     ...         ...
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858
#
# [26024289 rows x 4 columns]

# %%
# Cleaning movies
relevant_metadada = movies_metadata_df[["imdb_id", "id", "original_title", "overview"]]
relevant_metadada
relevant_rating = movies_ratings_df[["movieId", "rating"]]
relevant_rating
idToNumRatings = dict()
idToRatingSum = dict()
# i = 0
for row in relevant_rating.iterrows():
  # if i > 50000:
  #   break
  movieId = row[1]['movieId']
  # print(movieId)
  rating = row[1]['rating']
  # print(rating)
  if movieId in idToNumRatings:
    idToNumRatings[movieId] = idToNumRatings[movieId] + 1
  else:
    idToNumRatings[movieId] = 1
  if movieId in idToRatingSum:
    idToRatingSum[movieId] = idToRatingSum[movieId] + rating
  else:
    idToRatingSum[movieId] = rating
  # i = i + 1

the_ids = movies_metadata_df["id"]
print(len(idToNumRatings))
print(len(idToRatingSum))
print(len(relevant_rating))
print(len(relevant_metadada))
print(len(the_ids))



# test = list(relevant_rating['movieId'])
# casted = list()
# for t in test:
#   casted.append(str(t))
# # for t in casted:
# #   print(type(t))
# converted = pd.DataFrame(casted)
# converted
# # print(len(converted))
# # print(len(relevant_rating))
# # relevant_rating['movieId'] = converted[[0]]
# # relevant_rating
# converted

# # # relevant_metadada.set_index('id').join(relevant_metadada.set_index('id'))
# # relevant_metadada.join(relevant_rating.set_index('movieId'), on='imdb_id')
# Out:
# 45115
# 45115
# 26024289
# 45466
# 45466

# %% [markdown]
# ## TV Shows Data

# %%
tv_shows_titles_df = pd.read_csv('/content/drive/My Drive/CIS450 Project/TV Shows/titles.csv')
tv_shows_credits_df = pd.read_csv('/content/drive/My Drive/CIS450 Project/TV Shows/tv_credits.csv')

# %%
relevant_rating = movies_ratings_df[["userId", "movieId", "rating"]].drop_duplicates()
relevant_rating
relevant_rating.to_csv('ratings.csv',index=False)

# %%
relevant_rating = movies_ratings_df[["userId", "movieId", "rating"]]
relevant_rating
# Out:
#           userId  movieId  rating
# 0              1      110     1.0
# 1              1      147     4.5
# 2              1      858     5.0
# 3              1     1221     5.0
# 4              1     1246     5.0
# ...          ...      ...     ...
# 26024284  270896    58559     5.0
# 26024285  270896    60069     5.0
# 26024286  270896    63082     4.5
# 26024287  270896    64957     4.5
# 26024288  270896    71878     2.0
#
# [26024289 rows x 3 columns]

# %%
relevant_metadada = movies_metadata_df[["id", "original_title", "overview"]]
relevant_metadada = relevant_metadada.drop_duplicates()
relevant_metadada['overview'] = relevant_metadada['overview'].str.replace('|',' ')
relevant_metadada.to_csv('movies.csv',index=False,sep='|')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
